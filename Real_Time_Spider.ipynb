# %% [markdown]
# # <center> Real time spider </center>

# %%
import time
import schedule

# %% [markdown]
# ## Scrapy in real time

# %%
# %cd NoSQLProject/crypto/crypto/spiders/

# %%
def lunch_every_day():
    try:
        # !scrapy crawl cryptoArticles
        print("------------")
        # !scrapy crawl cryptoMarket
        print("------------")
        # !scrapy crawl GoogleArticles
    except:
        print("Unexpected error:", sys.exc_info()[0])
        raise

# %%
schedule.every().day.at("20:44").do(lunch_every_day) # every day at 10AM 
#schedule.every(1).minutes.do(lunch_every_day) # every minutes 
#schedule.every().wednesday.do(lunch_every_day) # every wensday
# Out:
# Every 1 day at 20:44:00 do lunch_every_day() (last run: [never], next run: 2021-05-05 20:44:00)

# %%
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# 2021-05-05 20:44:01 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: crypto)
# 2021-05-05 20:44:01 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug 13 2019, 15:17:50) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.2.1, Platform Darwin-20.3.0-x86_64-i386-64bit
# 2021-05-05 20:44:01 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-05-05 20:44:01 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crypto',
#  'COOKIES_ENABLED': False,
#  'NEWSPIDER_MODULE': 'crypto.spiders',
#  'SPIDER_MODULES': ['crypto.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
# 2021-05-05 20:44:01 [scrapy.extensions.telnet] INFO: Telnet Password: 771676663003bc24
# ...
